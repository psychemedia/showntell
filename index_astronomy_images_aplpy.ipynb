# %% [markdown]
# # Jupyter Notebooks - Astronomy Images - `aplpy`

# %% [markdown]
# ## `aplpy`
#
# `aplypy`, the [*Astronomical Plotting Library in Python*](https://aplpy.github.io/), is a Python module aimed at producing publication-quality plots of astronomical imaging data in FITS format.

# %%
# %matplotlib inline

import aplpy

# %%
gc = aplpy.FITSFigure('./data/502nmos.fits')
gc.show_grayscale()
# Out:
# WARNING: FITSFixedWarning: EQUINOX = 'J2000 ' / equinox of the celestial coordinate system
# a floating-point value was expected. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Changed '17/01/95          ' to '1995-01-17''. [astropy.wcs.wcs]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# INFO: Auto-setting vmin to -6.084e+00 [aplpy.core]
# INFO: Auto-setting vmax to  3.858e+01 [aplpy.core]

# %%
gc = aplpy.FITSFigure('./data/502nmos.fits')
gc.show_colorscale()
gc.add_grid()
gc.tick_labels.set_font(size='small')
# Out:
# WARNING: FITSFixedWarning: EQUINOX = 'J2000 ' / equinox of the celestial coordinate system
# a floating-point value was expected. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Changed '17/01/95          ' to '1995-01-17''. [astropy.wcs.wcs]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# WARNING: Cannot determine equinox. Assuming J2000. [aplpy.wcs_util]
# INFO: Auto-setting vmin to -6.084e+00 [aplpy.core]
# INFO: Auto-setting vmax to  3.858e+01 [aplpy.core]
